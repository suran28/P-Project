# %%
pip install xmltodict
# Out:
# ...
#
# ...

# %%
url = "http://openapi.q-net.or.kr/api/service/rest/InquiryListNationalQualifcationSVC%20/getList?ServiceKey=qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D"
result = requests.get(url)
soup = BeautifulSoup(result.text, "lxml")
print(soup)

# %%
# 모듈 import
import requests
import pprint

#인증키 입력
encoding = 'qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D'
decoding = 'qUjfGRDJasifRNhDiZxLmTm/BUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg=='

#url 입력
url = 'http://openapi.q-net.or.kr/api/service/rest/InquiryListNationalQualifcationSVC/getList'
params ={'serviceKey' : 'qUjfGRDJasifRNhDiZxLmTm/BUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg==' }

response = requests.get(url, params=params)

response = requests.get(url, params=params)

# xml 내용
content = response.text

# 깔끔한 출력 위한 코드
pp = pprint.PrettyPrinter(indent=4)
#print(pp.pprint(content))

# %% [markdown]
# https://velog.io/@yeomyaloo/%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EA%B3%B5%EA%B3%B5%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%A5%BC-%EC%82%AC%EC%9A%A9%ED%95%B4%EB%B3%B4%EC%9E%90
# 국가 자격 종목 목록 정보

# %% [markdown]
# # 데이터 json 변환 후 출력

# %%
#1. 한국산업인력공단_국가자격 종목 목록 정보
import requests, xmltodict,json

url = 'http://openapi.q-net.or.kr/api/service/rest/InquiryListNationalQualifcationSVC/getList'
params ={'serviceKey' : 'qUjfGRDJasifRNhDiZxLmTm/BUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg==' }

response = requests.get(url, params=params)

# %%
response = requests.get(url, params = params)
content = response.content
dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body']['items'])
json_object = json.loads(jsonString)
json_object
# Out:
# {'item': [{'jmcd': '0752',
#    'jmfldnm': '가스기술사',
#    'mdobligfldcd': '251',
#    'mdobligfldnm': '안전관리',
#    'obligfldcd': '25',
#    'obligfldnm': '안전관리',
#    'qualgbcd': 'T',
#    'qualgbnm': '국가기술자격',
#    'seriescd': '01',
#    'seriesnm': '기술사'},
#   {'jmcd': '0080',
#    'jmfldnm': '건설기계기술사',
#    'mdobligfldcd': '162',
#    'mdobligfldnm': '기계장비설비.설치',
#    'obligfldcd': '16',
#    'obligfldnm': '기계',
#    'qualgbcd': 'T',
#    'qualgbnm': '국가기술자격',
#    'seriescd': '01',
#    'seriesnm': '기술사'},
#   {'jmcd': '0740',
#    'jmfldnm': '건설안전기술사',
#    'mdobligfldcd': '251',
#    'mdobligfldnm': '안전관리',
#    'obligfldcd': '25',
#    'obligfldnm': '안전관리',
#    'qualgbcd': 'T',
#    'qualgbnm': '국가기술자격',
#    'seriescd': '01',
#    'seriesnm': '기술사'},
#   {'jmcd': '0490',
#    'jmfldnm': '건축구조기술사',
#    'mdobligfldcd': '141',
#    'mdobligfldnm': '건축',
#    'obligfldcd': '14',
#    'obligfldnm': '건설',
#    'qualgbcd': 'T',
#    'qualgbnm': '국가기술자격',
#    'seriescd': '01',
# ...

# %%
# 이건 아님
for i in json_object['item']:
    print(f"자격구분명: {i['qualgbnm']}")
    print(f"계열명: {i['seriesnm']}")
    print(f"종목코드: {i['jmcd']}")
    print(f"종목명: {i['jmfldnm']}")
    print(f"대직무분야코드: {i['obligfldcd']}")
    print(f"대직무분야명: {i['obligfldnm']}")
    print(f"중직무분야코드: {i['mdobligfldcd']}")
    print(f"중직무분야명: {i['mdobligfldnm']}")
    
    print()
# Out:
# 자격구분명: 국가기술자격
# 계열명: 기술사
# 종목코드: 0752
# 종목명: 가스기술사
# 대직무분야코드: 25
# 대직무분야명: 안전관리
# 중직무분야코드: 251
# 중직무분야명: 안전관리
#
# 자격구분명: 국가기술자격
# 계열명: 기술사
# 종목코드: 0080
# 종목명: 건설기계기술사
# 대직무분야코드: 16
# 대직무분야명: 기계
# 중직무분야코드: 162
# 중직무분야명: 기계장비설비.설치
#
# 자격구분명: 국가기술자격
# 계열명: 기술사
# 종목코드: 0740
# 종목명: 건설안전기술사
# 대직무분야코드: 25
# 대직무분야명: 안전관리
# 중직무분야코드: 251
# 중직무분야명: 안전관리
#
# 자격구분명: 국가기술자격
# 계열명: 기술사
# 종목코드: 0490
# 종목명: 건축구조기술사
# 대직무분야코드: 14
# 대직무분야명: 건설
# 중직무분야코드: 141
# 중직무분야명: 건축
#
# 자격구분명: 국가기술자격
# 계열명: 기술사
# 종목코드: 0501
# 종목명: 건축기계설비기술사
# 대직무분야코드: 14
# 대직무분야명: 건설
# 중직무분야코드: 141
# 중직무분야명: 건축
#
# 자격구분명: 국가기술자격
# 계열명: 기술사
# 종목코드: 0510
# 종목명: 건축시공기술사
# 대직무분야코드: 14
# 대직무분야명: 건설
# 중직무분야코드: 141
# 중직무분야명: 건축
#
# 자격구분명: 국가기술자격
# 계열명: 기술사
# 종목코드: 0502
# 종목명: 건축전기설비기술사
# 대직무분야코드: 20
# 대직무분야명: 전기.전자
# 중직무분야코드: 201
# 중직무분야명: 전기
#
# 자격구분명: 국가기술자격
# 계열명: 기술사
# 종목코드: 0511
# 종목명: 건축품질시험기술사
# 대직무분야코드: 14
# 대직무분야명: 건설
# 중직무분야코드: 141
# 중직무분야명: 건축
#
# 자격구분명: 국가기술자격
# 계열명: 기술사
# 종목코드: 0760
# 종목명: 공장관리기술사
# 대직무분야코드: 02
# ...

# %%
#2. 한국산업인력공단_국가자격시험 시험장소 정보
import requests, xmltodict,json

url = "http://openapi.q-net.or.kr/api/service/rest/InquiryExamAreaSVC/getList?brchCd=01&ServiceKey=qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D".format(key)
params ={'serviceKey' : 'qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D' }

response = requests.get(url, params=params)

# %%
response = requests.get(url, params = params)
content = response.content
dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body']['items'])
json_object = json.loads(jsonString)
json_object
# Out:
# {'item': [{'address': '강원도 삼척시 중앙로 346 (교동)',
#    'brchCd': '01',
#    'brchNm': '서울',
#    'examAreaGbNm': '대학교',
#    'examAreaNm': '강원대학교 삼척캠퍼스(전산정보원)[CBT시험실]_4실',
#    'plceLoctGid': '대학본부 옆 전산정보원',
#    'telNo': '0335706114'},
#   {'address': '경기 파주시 문산읍 당동리140',
#    'brchCd': '01',
#    'brchNm': '서울',
#    'examAreaGbNm': '고등학교',
#    'examAreaNm': '파주고등학교',
#    'plceLoctGid': None,
#    'telNo': '031-952-2647'},
#   {'address': '경기도 고양시 덕양구 고양대로 1361 (성사동)',
#    'brchCd': '01',
#    'brchNm': '서울',
#    'examAreaGbNm': '훈련기관(구사설기관)',
#    'examAreaNm': '고양직업전문학교',
#    'plceLoctGid': '3호선 원당역 5번출구 고양소방서 방향 10분',
#    'telNo': '031-967-0001'},
#   {'address': '경기도 고양시 덕양구 동헌로 61 (관산동)',
#    'brchCd': '01',
#    'brchNm': '서울',
#    'examAreaGbNm': '훈련기관(구사설기관)',
#    'examAreaNm': '서울중장비직업전문학교(실습장)',
#    'plceLoctGid': '경기도 고양시 덕양구 관산동 47-1 (내비게이션: 서울중장비직업전문학교 고양교육장 또는 연안중장비운전학원" 검색)',
#    'telNo': '031-969-2245'},
#   {'address': '경기도 고양시 덕양구 무원로 45 (행신동)',
# ...

# %%
#3. 한국산업인력공단_국가자격 종목별 자격정보
import requests, xmltodict,json

url = "http://openapi.q-net.or.kr/api/service/rest/%20InquiryInformationTradeNTQSVC/getList?jmCd=0752&ServiceKey=qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D".format(key)
params ={'serviceKey' : 'qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D' }

response = requests.get(url, params=params)

# %%
response = requests.get(url, params = params)
content = response.content
dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body']['items'])
json_object = json.loads(jsonString)
json_object
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[65], line 4
#       2 content = response.content
#       3 dic = xmltodict.parse(content)
# ----> 4 jsonString = json.dumps(dic['response']['body']['items'])
#       5 json_object = json.loads(jsonString)
#       6 json_object
#
# KeyError: 'body'

# %%
#4. 한국산업인력공단_국가자격 시험일정 조회 서비스
import requests, xmltodict,json

url = "http://apis.data.go.kr/B490007/qualExamSchd/getQualExamSchdList?dataFormat=xml&serviceKey=qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D&implYy=2020&numOfRows=10&pageNo=1&jmCd=7910&qualgbCd=T".format(key)
params ={'serviceKey' : 'qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D' }

response = requests.get(url, params=params)

# %%
response = requests.get(url, params = params)
content = response.content
dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body']['items'])
json_object = json.loads(jsonString)
json_object

# %%
#5. 한국산업인력공단_국가자격 접수 등 총괄 현황 데이터
import requests, xmltodict,json

url = "http://openapi.q-net.or.kr/api/service/rest/InquiryRecpTotPtcondSVC/getTrendList?baseYY=2018&jmCd=1320&trendDiv=01&pageNo=1&numOfRows=10&ServiceKey=qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D".format(key)
params ={'serviceKey' : 'qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D',
         'numOfRows': '1000',  # 페이지 크기를 충분히 크게 설정
        'pageNo': '5'}

response = requests.get(url, params=params)

# %%
response = requests.get(url, params = params)
content = response.content
dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body']['items'])
json_object = json.loads(jsonString)
json_object
# Out:
# {'item': [{'abseManCnt': '457',
#    'cnclManCnt': '273',
#    'dtlTrendClsifNm': '거주지역',
#    'dtlTrendDtlClsifNm': '강원',
#    'exameeCnt': '1122',
#    'grdNm': '기사',
#    'jmNm': '정보처리기사',
#    'passManCnt': '520',
#    'recvrCnt': '1852',
#    'trendDivNm': '성별',
#    'trendDtlDivNm': '남자'},
#   {'abseManCnt': '5817',
#    'cnclManCnt': '2996',
#    'dtlTrendClsifNm': '거주지역',
#    'dtlTrendDtlClsifNm': '경기',
#    'exameeCnt': '13974',
#    'grdNm': '기사',
#    'jmNm': '정보처리기사',
#    'passManCnt': '7274',
#    'recvrCnt': '22787',
#    'trendDivNm': '성별',
#    'trendDtlDivNm': '남자'},
#   {'abseManCnt': '780',
#    'cnclManCnt': '471',
#    'dtlTrendClsifNm': '거주지역',
#    'dtlTrendDtlClsifNm': '경남',
#    'exameeCnt': '2043',
#    'grdNm': '기사',
#    'jmNm': '정보처리기사',
#    'passManCnt': '1012',
#    'recvrCnt': '3294',
#    'trendDivNm': '성별',
#    'trendDtlDivNm': '남자'},
#   {'abseManCnt': '564',
#    'cnclManCnt': '358',
#    'dtlTrendClsifNm': '거주지역',
# ...

# %%
#6. 한국산업인력공단_국가자격취득자 현황 조회 서비스
import requests, xmltodict,json

url = "http://apis.data.go.kr/B490007/qualAcquPtcond/getQualAcquPtcond?serviceKey=qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D&numOfRows=10&pageNo=1&dataFormat=xml&acquYy=2020&qualgbCd=T".format(key)
params ={'serviceKey' : 'qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D' }

response = requests.get(url, params=params)

# %%
response = requests.get(url, params = params)
content = response.content
dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body']['items'])
json_object = json.loads(jsonString)
json_object
# Out:
# {'item': [{'acquYy': '2020',
#    'acquMm': '01',
#    'qualgbCd': 'T',
#    'qualgbNm': '국가기술자격',
#    'rgnCd': '001',
#    'rgnNm': '서울',
#    'ageGrupCd': '1',
#    'ageGrupNm': '10대',
#    'genderCd': 'F',
#    'genderNm': '여성',
#    'seriesCd': '04',
#    'seriesNm': '기능사',
#    'jmCd': '7796',
#    'jmNm': '컴퓨터그래픽스운용기능사',
#    'acquCnt': '1'},
#   {'acquYy': '2020',
#    'acquMm': '01',
#    'qualgbCd': 'T',
#    'qualgbNm': '국가기술자격',
#    'rgnCd': '001',
#    'rgnNm': '서울',
#    'ageGrupCd': '1',
#    'ageGrupNm': '10대',
#    'genderCd': 'M',
#    'genderNm': '남성',
#    'seriesCd': '04',
#    'seriesNm': '기능사',
#    'jmCd': '7450',
#    'jmNm': '금속도장기능사',
#    'acquCnt': '1'},
#   {'acquYy': '2020',
#    'acquMm': '01',
#    'qualgbCd': 'T',
#    'qualgbNm': '국가기술자격',
#    'rgnCd': '001',
#    'rgnNm': '서울',
#    'ageGrupCd': '1',
#    'ageGrupNm': '10대',
#    'genderCd': 'M',
#    'genderNm': '남성',
#    'seriesCd': '04',
#    'seriesNm': '기능사',
#    'jmCd': '7992',
# ...

# %%
#7. 한국산업인력공단_국가자격 종목 관련 정보(결격사유, 유사종목) 조회
import requests, xmltodict,json

url = "http://openapi.q-net.or.kr/api/service/rest/InquiryJmcdInfoSVC/getGrupList?ServiceKey=qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D&numOfRows=10&pageNo=1".format(key)
params ={'serviceKey' : 'qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D' }

response = requests.get(url, params=params)

# %%
response = requests.get(url, params = params)
content = response.content
dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body']['items'])
json_object = json.loads(jsonString)
json_object
# Out:
# {'item': [{'alikeGrupNm': '건축', 'jmNm': '건축품질시험기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '건축', 'jmNm': '건축구조기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '건축', 'jmNm': '건축기계설비기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '건축', 'jmNm': '건축전기설비기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '금속', 'jmNm': '금속가공기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '금속', 'jmNm': '금속재료기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '전기', 'jmNm': '전기안전기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '전기', 'jmNm': '전기철도기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '전기', 'jmNm': '전기응용기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '정보', 'jmNm': '정보관리기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '정보', 'jmNm': '정보통신기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '철도', 'jmNm': '철도차량기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '철도', 'jmNm': '철도기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '철도', 'jmNm': '철도신호기술사', 'seriesNm': '기술사'},
#   {'alikeGrupNm': '토목', 'jmNm': '토목구조기술사', 'seriesNm': '기술사'},
# ...

# %%
#8. 한국산업인력공단_전공별 국가기술자격 취득현황
import requests, xmltodict,json

url = "http://openapi.q-net.or.kr/api/service/rest/InquiryMjrQualSVC/getList?pageNo=1&numOfRows=10&baseYY=2020&grdCd=31&ServiceKey=qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D".format(key)
params ={'serviceKey' : 'qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D' }

response = requests.get(url, params=params)

# %%
response = requests.get(url, params = params)
content = response.content
dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body']['items'])
json_object = json.loads(jsonString)
json_object
# Out:
# {'item': [{'accumAcquCnt': '1',
#    'grdNm': '산업기사',
#    'jmNm': '공기압축기산업기사',
#    'mdobligFldNm': '건설기계운전',
#    'mjrYnNm': '비관련전공',
#    'obligFldNm': '건설',
#    'statisYy': '2020',
#    'yy1AcquCnt': '1',
#    'yy2AcquCnt': '0',
#    'yy3AcquCnt': '0',
#    'yy4AcquCnt': '0',
#    'yy5AcquCnt': '0',
#    'yy6AcquCnt': '0'},
#   {'accumAcquCnt': '2',
#    'grdNm': '산업기사',
#    'jmNm': '굴삭기기능사1급',
#    'mdobligFldNm': '건설기계운전',
#    'mjrYnNm': '비관련전공',
#    'obligFldNm': '건설',
#    'statisYy': '2020',
#    'yy1AcquCnt': '2',
#    'yy2AcquCnt': '0',
#    'yy3AcquCnt': '0',
#    'yy4AcquCnt': '0',
#    'yy5AcquCnt': '0',
#    'yy6AcquCnt': '0'},
#   {'accumAcquCnt': '3',
#    'grdNm': '산업기사',
#    'jmNm': '불도저산업기사',
#    'mdobligFldNm': '건설기계운전',
#    'mjrYnNm': '비관련전공',
#    'obligFldNm': '건설',
#    'statisYy': '2020',
#    'yy1AcquCnt': '3',
#    'yy2AcquCnt': '0',
#    'yy3AcquCnt': '0',
#    'yy4AcquCnt': '0',
#    'yy5AcquCnt': '0',
#    'yy6AcquCnt': '0'},
# ...

# %%
#9. 한국산업인력공단_국가자격 응시자격 관련 현황 데이터
import requests, xmltodict,json

url = "http://openapi.q-net.or.kr/api/service/rest/InquiryExamQualPtcondSVC/getExamRecpList?baseYY=2018&pageNo=1&numOfRows=10&ServiceKey=qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D".format(key)
params ={'serviceKey' : 'qUjfGRDJasifRNhDiZxLmTm%2FBUOKOgYdzyBk1RRcOg9EGlFjE3KfP2ABf6exHYkmgLoqi6IsDSsOfXuPd0bWsg%3D%3D' }

response = requests.get(url, params=params)

# %%
response = requests.get(url, params = params)
content = response.content
dic = xmltodict.parse(content)
jsonString = json.dumps(dic['response']['body']['items'])
json_object = json.loads(jsonString)
json_object
# Out:
# {'item': [{'emqualCd': 'T101',
#    'emqualDispNm': '기사 자격 취득후 동일 및 유사직무분야에서 4년이상 실무에 종사한 자',
#    'grdCd': '10',
#    'grdGubun': '10114',
#    'grdNm': '기술사',
#    'implSeq': '114',
#    'implYy': '2018',
#    'pilPassCnt': '343',
#    'recptCnt': '6556',
#    'silPassCnt': '374'},
#   {'emqualCd': 'T132',
#    'emqualDispNm': '5년제 대학 관련학과 1/2이상 마친 후 동일 및 유사직무분야에서 8년이상 실무에 종사한 자',
#    'grdCd': '10',
#    'grdGubun': '10114',
#    'grdNm': '기술사',
#    'implSeq': '114',
#    'implYy': '2018',
#    'pilPassCnt': '0',
#    'recptCnt': '3',
#    'silPassCnt': '0'},
#   {'emqualCd': 'T131',
#    'emqualDispNm': '4년제 대학 관련학과 1/2이상 마친 후 동일 및 유사직무분야에서 8년이상 실무에 종사한 자',
#    'grdCd': '10',
#    'grdGubun': '10114',
#    'grdNm': '기술사',
#    'implSeq': '114',
#    'implYy': '2018',
#    'pilPassCnt': '8',
#    'recptCnt': '151',
#    'silPassCnt': '4'},
#   {'emqualCd': 'T130',
#    'emqualDispNm': '동일 및 유사직무분야에서 9년이상 실무에 종사한 자',
#    'grdCd': '10',
#    'grdGubun': '10114',
# ...

# %% [markdown]
# =================]
